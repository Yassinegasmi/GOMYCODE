# %%
import pandas as pd
import numpy as np

exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data , index=labels)
print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df.head(3)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
print(df.dropna())
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
new_row = {'name':'suresh', 'score':15.5, 'attemps':1, 'qualify':'yes'}
x = df.append(new_row, ignore_index=True)
x
# Out:
#          name  score  attempts qualify  attemps
# 0   Anastasia   12.5       1.0     yes      NaN
# 1        Dima    9.0       3.0      no      NaN
# 2   Katherine   16.5       2.0     yes      NaN
# 3       James    NaN       3.0      no      NaN
# 4       Emily    9.0       2.0      no      NaN
# 5     Michael   20.0       3.0     yes      NaN
# 6     Matthew   14.5       1.0     yes      NaN
# 7       Laura    NaN       1.0      no      NaN
# 8       Kevin    8.0       2.0      no      NaN
# 9       Jonas   19.0       1.0     yes      NaN
# 10     suresh   15.5       NaN     yes      1.0

# %%
del df['attemps']

# %%
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df['success']=[i=1 if i>10 else i=0 for i in df.score]
# Out:
#   File "<ipython-input-85-3b09035ddeaa>", line 1
#     df['success']=[i=1 if i>10 else i=0 for i in df.score]
#                     ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#         name  score  attempts qualify  success
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# d      James    NaN         3      no        0
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# h      Laura    NaN         1      no        0
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1

# %%
df = pd.read_csv('my_data')

# %%
print(df.to_string())
# Out:
#         name  score  attempts qualify  success
# a  Anastasia   12.5         1     yes        1
# b       Dima    9.0         3      no        0
# c  Katherine   16.5         2     yes        1
# d      James    NaN         3      no        0
# e      Emily    9.0         2      no        0
# f    Michael   20.0         3     yes        1
# g    Matthew   14.5         1     yes        1
# h      Laura    NaN         1      no        0
# i      Kevin    8.0         2      no        0
# j      Jonas   19.0         1     yes        1
